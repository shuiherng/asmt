# %%
# EXTRACT_IMAGES = True
DEBUG_OUTPUT = True
IMAGE_PATH = './images'
JSON_PATH = 'whois_info.json'

import json
import os
import pytesseract
import re
import requests
import whois

from bs4 import BeautifulSoup
from tqdm import tqdm

# set to tesseract path where necessary
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
target = "https://securelist.com/apt-phantomlance/96772/"

"""
Modified from:
https://daringfireball.net/2010/07/improved_regex_for_matching_urls
Changes made:
1. Matched actual URLs without any resource links behind
2. Allowed matching of [.] in URL names to extra data from site
"""
url_regex = r"""(?i)\b((?:[a-z][\w-]+:(?:\/{1,3}|[a-z0-9%])|www\d{0,3}[.]|[a-z0-9.\-]+(?:[.]|\[\.\])[a-z]{1,4}\/?)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))*(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))"""

"""
MD5 hash matcher
"""
hash_regex = r"""[a-f0-9]{32,}"""

# %%
def debug(*s):
    if DEBUG_OUTPUT:
        print(s)

# %%
def validate_url(link):
    # this can be written directly as a single line but it's harder to read
    
    if (len(link) == 0 or 
            link.startswith('com.') or  # java packages
            link.startswith('org.') or
            # first occurrence of : is not proceeded with /
            (link.find(':') != -1 and link.find('/') - link.find(':') != 1) or
            # parentheses before query in url
            (link.find('(') != -1 and (link.find('?') > link.find('(') or link.find('?') == -1)) or
            link == "data.raw"): # custom exclusion
        return False
    
    # technically possible to do a reference check against all TLDs and then filter unknowns
    domain = process_url(link)[1]
    if domain.find(',') != -1: # comma in domain name
        return False 
    
    return True

# %%
def process_url(link):
    if "hxxp" in link:
        link = link.replace("hxxp", "http") 
    link = link.replace('[.]', '.')
    
    domain = link
    if "://" in domain:
        domain = domain.split("://")[1]
    domain = domain.split('/')[0]
    domain = domain.split('?')[0]
    return (link, domain)

# %%
def download(url, pathname):
    # stolen from https://www.thepythoncode.com/article/download-files-python
    if not os.path.isdir(pathname):
        os.makedirs(pathname)
    response = requests.get(url, stream = True)
    file_size = int(response.headers.get("Content-Length", 0))
    filename = os.path.join(pathname, url.split('/')[-1])
    progress = tqdm(response.iter_content(1024), f"Downloading {filename}",
                    total=file_size, unit="B", unit_scale=True, unit_divisor=1024)
    with open(filename, 'wb') as f:
        for data in progress:
            f.write(data)
            progress.update(len(data))

# %%
raw = requests.get(target)
page = raw.content

soup = BeautifulSoup(page, 'html5lib')
article = soup.find_all('div', class_ = 'c-wysiwyg')[0]

# %%
# get urls from raw site
urls = [l[0] for l in re.findall(url_regex, article.get_text())]
urls = [process_url(x) for x in filter(validate_url, urls)]

# %%
# process images
# if EXTRACT_IMAGES:
debug("Extracting Images")
images = [i.get('src') for i in soup.find_all('div', class_ = 'c-wysiwyg')[0].findChildren('img')]
image_paths = [IMAGE_PATH + '/' + i.split('/')[-1] for i in images]
for url in images:
    download(url, IMAGE_PATH)
# Out:
# Extracting Images
# Downloading ./images\sl_phantomlance_01.png:   0%|                                   | 113/113k [00:00<00:03, 37.9kB/s]
# Downloading ./images\sl_phantomlance_02.png:   0%|                                   | 200/199k [00:00<00:15, 13.4kB/s]
# Downloading ./images\sl_phantomlance_03.png:   0%|                                 | 24.0/23.3k [00:00<00:01, 12.0kB/s]
# Downloading ./images\sl_phantomlance_04.png:   0%|                                 | 29.0/28.3k [00:00<00:03, 9.58kB/s]
# Downloading ./images\sl_phantomlance_05.png:   0%|                                 | 41.0/40.3k [00:00<00:03, 13.7kB/s]
# Downloading ./images\sl_phantomlance_06.png:   0%|                                 | 25.0/24.4k [00:00<00:02, 8.33kB/s]
# Downloading ./images\sl_phantomlance_07.png:   0%|                                 | 35.0/34.9k [00:00<00:02, 17.7kB/s]
# Downloading ./images\sl_phantomlance_08.png:   0%|                                 | 48.0/47.6k [00:00<00:06, 8.00kB/s]
# Downloading ./images\sl_phantomlance_09.png:   0%|                                 | 10.0/9.08k [00:00<00:01, 5.00kB/s]
# Downloading ./images\sl_phantomlance_10.png:   0%|                                 | 61.0/60.8k [00:00<00:07, 8.72kB/s]
# Downloading ./images\sl_phantomlance_11.png:   0%|                                 | 12.0/11.3k [00:00<00:01, 6.00kB/s]
# Downloading ./images\sl_phantomlance_12.png:   0%|                                 | 35.0/34.4k [00:00<00:02, 17.5kB/s]
# Downloading ./images\sl_phantomlance_13.png:   0%|                                 | 24.0/23.6k [00:00<00:02, 12.0kB/s]
# Downloading ./images\sl_phantomlance_14.png:   0%|                                 | 26.0/25.7k [00:00<00:02, 13.0kB/s]
# Downloading ./images\sl_phantomlance_15.png:   0%|                                   | 102/101k [00:00<00:06, 16.9kB/s]
# Downloading ./images\sl_phantomlance_16.png:   0%|                                   | 530/529k [00:00<00:35, 15.2kB/s]
# Downloading ./images\sl_phantomlance_17.png:   0%|                                 | 38.0/37.3k [00:00<00:03, 12.7kB/s]
# Downloading ./images\sl_phantomlance_18.png:   0%|                                   | 142/141k [00:00<00:11, 12.9kB/s]
# Downloading ./images\sl_phantomlance_19.png:   0%|                                 | 99.0/98.6k [00:00<00:06, 16.5kB/s]
# Downloading ./images\sl_phantomlance_20.png:   0%|                                 | 28.0/27.3k [00:00<00:01, 14.0kB/s]
# Downloading ./images\sl_phantomlance_21.png:   0%|                                 | 51.0/50.5k [00:00<00:06, 8.50kB/s]
# Downloading ./images\sl_phantomlance_22.png:   0%|                                 | 31.0/30.1k [00:00<00:02, 10.3kB/s]
# Downloading ./images\sl_phantomlance_23.png:   0%|                                 | 45.0/44.4k [00:00<00:05, 8.99kB/s]

# %%
image_urls = []
image_hashes = []
for img in image_paths:
    img_text = pytesseract.image_to_string(img)
    image_urls += [l[0] for l in re.findall(url_regex, img_text)]
    image_hashes += re.findall(hash_regex, img_text)

# %%
image_urls = [process_url(x) for x in filter(validate_url, image_urls)]

# %%
# get hashes
hashes = re.findall(hash_regex, article.get_text())

# %%
# remove urls duplicates
urls = list(set(urls))
image_urls = list(set(urls))
# generate URL output
all_urls = urls + image_urls
max_domain_length = len(max([_[1] for _ in all_urls], key = len)) + 4
print("SRC  DOMAIN".ljust(max_domain_length) + "URL")
print("-" * (max_domain_length + 15))
for url, domain in urls:
    print("SRC  " + domain.ljust(max_domain_length) + url)
for url, domain in image_urls:
    print("IMG  " + domain.ljust(max_domain_length) + url)
# Out:
# SRC  DOMAIN                        URL
# --------------------------------------------------
# SRC  video.viodger.com                  video.viodger.com
# SRC  log4jv.info                        log4jv.info
# SRC  viodger.com                        viodger.com
# SRC  cerisecaird.com                    cerisecaird.com
# SRC  bulknewsexpress.news               bulknewsexpress.news
# SRC  ps.andreagahuvrauvin.com           ps.andreagahuvrauvin.com
# SRC  kaspersky.com                      kaspersky.com
# SRC  androidappsapk.co                  https://androidappsapk.co/detail-cham-soc-be-yeu-babycare/
# SRC  luxury.BeerAddress                 luxury.BeerAddress
# SRC  mine.remaariegarcia.com            mine.remaariegarcia.com
# SRC  egg.stralisemariegar.com           egg.stralisemariegar.com
# SRC  us.jaxonsorensen.club              us.jaxonsorensen.club
# SRC  ming.chujong.com                   ming.chujong.com
# SRC  quam.viperse.com                   quam.viperse.com
# SRC  sqllitlever.info                   sqllitlever.info
# SRC  inc.graceneufville.com             inc.graceneufville.com
# SRC  apkpourandroid.com                 https://apkpourandroid.com
# SRC  api.anaehler.com                   api.anaehler.com
# SRC  sadma.knrowz.com                   sadma.knrowz.com
# SRC  apk.support                        https://apk.support/
# SRC  apkcombo.com                       https://apkcombo.com
# SRC  game2015.net                       game2015.net
# SRC  anofrio.com                        anofrio.com
# SRC  osloger.biz                        osloger.biz
# SRC  www.tin247.com                     www.tin247.com
# SRC  apk.support                        https://apk.support/app-en/com.codedexon.churchaddress
# SRC  apkpure.ai                         https://apkpure.ai/ads-skipper
# SRC  www.mediafire.com                  http://www.mediafire.com/file/1elber8zl34tag4/framaroot-xpro.apk
# SRC  ckoen.dmkatti.com                  ckoen.dmkatti.com
# SRC  att.illagedrivestralia.xyz         att.illagedrivestralia.xyz
# SRC  nhaccuatui.android.zyngacdn.com    nhaccuatui.android.zyngacdn.com
# SRC  jang.goongnam.com                  jang.goongnam.com
# SRC  cloud.anofrio.com                  cloud.anofrio.com
# SRC  itpk.mostmkru.com                  itpk.mostmkru.com
# SRC  log.osloger.biz                    log.osloger.biz
# SRC  widget.shoreoa.com                 widget.shoreoa.com
# SRC  cyn.ettebiermahalet.com            cyn.ettebiermahalet.com
# SRC  apkpure.com                        https://apkpure.com
# SRC  bit.catalinabonami.com             bit.catalinabonami.com
# SRC  download1825.mediafire.com         http://download1825.mediafire.com/tyxddh46orzg/1elber8zl34tag4/framaroot-xpro.apk
# SRC  113.171.224.175                    http://113.171.224.175/videoplayer/NhacCuaTuiDownloader.apk
# SRC  mtk.baimind.com                    mtk.baimind.com
# SRC  codedexon.churchaddress            codedexon.churchaddress
# SRC  paste.christienollmache.xyz        paste.christienollmache.xyz
# SRC  browsersyn.com                     browsersyn.com
# SRC  ssl.arkouthrie.com                 ssl.arkouthrie.com
# SRC  file.log4jv.info                   file.log4jv.info
# SRC  hr.halettebiermann.com             hr.halettebiermann.com
# SRC  term.ursulapaulet.com              term.ursulapaulet.com
# SRC  staff.kristianfiedler.club         staff.kristianfiedler.club
# SRC  mokkha.goongnam.com                mokkha.goongnam.com
# SRC  aki.viperse.com                    aki.viperse.com
# SRC  taiphanmemfacebookmoi.info         taiphanmemfacebookmoi.info
# SRC  download.com.vn                    http://download.com.vn/android/download/nhaccuatui-downloader/31798
# SRC  s3.hiahornber.com                  s3.hiahornber.com
# SRC  news.sqllitlever.info              news.sqllitlever.info
# SRC  nhaccuatui.android.zyngacdn.com    http://nhaccuatui.android.zyngacdn.com/NhacCuaTuiDownloader.apk
# SRC  anaehler.com                       anaehler.com
# IMG  viodger.com                        viodger.com
# IMG  log4jv.info                        log4jv.info
# IMG  bulknewsexpress.news               bulknewsexpress.news
# IMG  video.viodger.com                  video.viodger.com
# IMG  cerisecaird.com                    cerisecaird.com
# IMG  ps.andreagahuvrauvin.com           ps.andreagahuvrauvin.com
# IMG  kaspersky.com                      kaspersky.com
# IMG  androidappsapk.co                  https://androidappsapk.co/detail-cham-soc-be-yeu-babycare/
# IMG  luxury.BeerAddress                 luxury.BeerAddress
# IMG  mine.remaariegarcia.com            mine.remaariegarcia.com
# IMG  egg.stralisemariegar.com           egg.stralisemariegar.com
# IMG  ming.chujong.com                   ming.chujong.com
# IMG  quam.viperse.com                   quam.viperse.com
# IMG  sqllitlever.info                   sqllitlever.info
# IMG  apkpourandroid.com                 https://apkpourandroid.com
# IMG  api.anaehler.com                   api.anaehler.com
# IMG  anaehler.com                       anaehler.com
# IMG  sadma.knrowz.com                   sadma.knrowz.com
# IMG  apk.support                        https://apk.support/
# IMG  apkcombo.com                       https://apkcombo.com
# IMG  game2015.net                       game2015.net
# IMG  anofrio.com                        anofrio.com
# IMG  osloger.biz                        osloger.biz
# IMG  www.tin247.com                     www.tin247.com
# IMG  apk.support                        https://apk.support/app-en/com.codedexon.churchaddress
# IMG  apkpure.ai                         https://apkpure.ai/ads-skipper
# IMG  www.mediafire.com                  http://www.mediafire.com/file/1elber8zl34tag4/framaroot-xpro.apk
# IMG  ckoen.dmkatti.com                  ckoen.dmkatti.com
# IMG  att.illagedrivestralia.xyz         att.illagedrivestralia.xyz
# IMG  nhaccuatui.android.zyngacdn.com    nhaccuatui.android.zyngacdn.com
# IMG  news.sqllitlever.info              news.sqllitlever.info
# IMG  jang.goongnam.com                  jang.goongnam.com
# IMG  cloud.anofrio.com                  cloud.anofrio.com
# IMG  itpk.mostmkru.com                  itpk.mostmkru.com
# IMG  log.osloger.biz                    log.osloger.biz
# IMG  widget.shoreoa.com                 widget.shoreoa.com
# IMG  cyn.ettebiermahalet.com            cyn.ettebiermahalet.com
# IMG  apkpure.com                        https://apkpure.com
# IMG  bit.catalinabonami.com             bit.catalinabonami.com
# IMG  download1825.mediafire.com         http://download1825.mediafire.com/tyxddh46orzg/1elber8zl34tag4/framaroot-xpro.apk
# IMG  113.171.224.175                    http://113.171.224.175/videoplayer/NhacCuaTuiDownloader.apk
# IMG  mtk.baimind.com                    mtk.baimind.com
# IMG  codedexon.churchaddress            codedexon.churchaddress
# IMG  paste.christienollmache.xyz        paste.christienollmache.xyz
# IMG  browsersyn.com                     browsersyn.com
# IMG  ssl.arkouthrie.com                 ssl.arkouthrie.com
# IMG  file.log4jv.info                   file.log4jv.info
# IMG  hr.halettebiermann.com             hr.halettebiermann.com
# IMG  term.ursulapaulet.com              term.ursulapaulet.com
# IMG  staff.kristianfiedler.club         staff.kristianfiedler.club
# IMG  mokkha.goongnam.com                mokkha.goongnam.com
# IMG  aki.viperse.com                    aki.viperse.com
# IMG  taiphanmemfacebookmoi.info         taiphanmemfacebookmoi.info
# IMG  download.com.vn                    http://download.com.vn/android/download/nhaccuatui-downloader/31798
# IMG  s3.hiahornber.com                  s3.hiahornber.com
# IMG  us.jaxonsorensen.club              us.jaxonsorensen.club
# IMG  nhaccuatui.android.zyngacdn.com    http://nhaccuatui.android.zyngacdn.com/NhacCuaTuiDownloader.apk
# IMG  inc.graceneufville.com             inc.graceneufville.com

# %%
# remove duplicate hashes
hashes = list(set(hashes))
image_hashes = list(set(image_hashes))
max_hash_length = len(max(hashes + image_hashes, key = len))
print("SRC  HASHES (VERIFY HASH IF SRC IS IMG)\n" + "-" * (max_hash_length + 5))
for h in hashes:
    print("SRC  " + h)
for h in image_hashes:
    print("IMG  " + h)
# Out:
# SRC  HASHES (VERIFY HASH IF SRC IS IMG)
# ---------------------------------------------
# SRC  8b35b3956078fc28e5709c5439e4dcb0
# SRC  a795f662d10040728e916e1fd7570c1d
# SRC  d23472f47833049034011cad68958b46
# SRC  d1eb52ef6c2445c848157beaba54044f
# SRC  6bf9b834d841b13348851f2dc033773e
# SRC  3285ae59877c6241200f784b62531694
# SRC  83c423c36ecda310375e8a1f4348a35e
# SRC  8d5c64fdaae76bb74831c0543a7865c3
# SRC  ce5bae8714ddfca9eb3bb24ee60f042d
# SRC  306d3ed0a7c899b5ef9d0e3c91f05193
# SRC  0d5c03da348dce513bf575545493f3e3
# SRC  af44bb0dd464680395230ade0d6414cd
# SRC  7285f44fa75c3c7a27bbb4870fc0cdca
# SRC  94a3ca93f1500b5bd7fd020569e46589
# SRC  51f9a7d4263b3a565dec7083ca00340f
# SRC  b4706f171cf98742413d642b6ae728dc
# SRC  07e01c2fa020724887fc39e5c97eccee
# SRC  243e2c6433815f2ecc204ada4821e7d6
# SRC  7048d56d923e049ca7f3d97fb5ba9812
# SRC  0e7b59b601a1c7ecd6f2f54b5cd8416a
# SRC  2e49775599942815ab84d9de13e338b3
# SRC  79f06cb9281177a51278b2a33090c867
# SRC  e648a2cc826707aec33208408b882e31
# SRC  54777021c34b0aed226145fde8424991
# SRC  a097b8d49386c8aab0bb38bbfdf315b2
# SRC  8008bedaaebc1284b1b834c5fd9a7a71
# SRC  315f8e3da94920248676b095786e26ad
# SRC  5079cb166df41233a1017d5e0150c17a
# SRC  83cd59e3ed1ba15f7a8cadfe9183e156
# SRC  a330456d7ca25c88060dc158049f3298
# SRC  810ef71bb52ea5c3cfe58b8e003520dc
# SRC  641f0cc057e2ab43f5444c5547e80976
# SRC  b1990e19efaf88206f7bffe9df0d9419
# SRC  d61c18e577cfc046a6252775da12294f
# SRC  fe15c0eacdbf5a46bc9b2af9c551f86a
# SRC  50bfd62721b4f3813c2d20b59642f022
# SRC  2e06bbc26611305b28b40349a600f95c
# SRC  b107c35b4ca3e549bdf102de918749ba
# SRC  c630ab7b51f0c0fa38a4a0f45c793e24
# SRC  872a3dd2cd5e01633b57fa5b9ac4648d
# SRC  65d399e6a77acf7e63ba771877f96f8e
# SRC  0e7c2adda3bc65242a365ef72b91f3a8
# SRC  c399d93146f3d12feb32da23b75304ba
# IMG  34825c728dbdb46459512739dcb7e52e
# IMG  b9a33c13ddc20e3829482cb9e8976cc4d8805805
# IMG  8322b54b7c6f2a622671ea33c0b60061

# %%
# part 2: extract whois information
print("Extracting whois information from domain list.")
domain = {'src': [], 'img' : []}
for u in urls:
    try:
        a = whois.query(u[1])
        domain['src'].append(a.__dict__)
    except:
        print("unknown domain: " + u[1])
        
for u in image_urls:
    try:
        a = whois.query(u[1])
        domain['img'].append(a.__dict__)
    except:
        print("unknown domain: " + u[1])
# Out:
# Extracting whois information from domain list.
# unknown domain: bulknewsexpress.news
# unknown domain: luxury.BeerAddress
# unknown domain: ming.chujong.com
# unknown domain: inc.graceneufville.com
# unknown domain: apkpourandroid.com
# unknown domain: sadma.knrowz.com
# unknown domain: apk.support
# unknown domain: apkcombo.com
# unknown domain: game2015.net
# unknown domain: anofrio.com
# unknown domain: osloger.biz
# unknown domain: apk.support
# unknown domain: apkpure.ai
# unknown domain: nhaccuatui.android.zyngacdn.com
# unknown domain: jang.goongnam.com
# unknown domain: itpk.mostmkru.com
# unknown domain: log.osloger.biz
# unknown domain: 113.171.224.175
# unknown domain: mtk.baimind.com
# unknown domain: codedexon.churchaddress
# unknown domain: browsersyn.com
# unknown domain: term.ursulapaulet.com
# unknown domain: mokkha.goongnam.com
# unknown domain: taiphanmemfacebookmoi.info
# unknown domain: download.com.vn
# unknown domain: nhaccuatui.android.zyngacdn.com
# unknown domain: bulknewsexpress.news
# unknown domain: luxury.BeerAddress
# unknown domain: ming.chujong.com
# unknown domain: apkpourandroid.com
# unknown domain: sadma.knrowz.com
# unknown domain: apk.support
# unknown domain: apkcombo.com
# unknown domain: game2015.net
# unknown domain: anofrio.com
# unknown domain: osloger.biz
# unknown domain: apk.support
# unknown domain: apkpure.ai
# unknown domain: nhaccuatui.android.zyngacdn.com
# unknown domain: jang.goongnam.com
# unknown domain: itpk.mostmkru.com
# unknown domain: log.osloger.biz
# unknown domain: 113.171.224.175
# unknown domain: mtk.baimind.com
# unknown domain: codedexon.churchaddress
# unknown domain: browsersyn.com
# unknown domain: term.ursulapaulet.com
# unknown domain: mokkha.goongnam.com
# unknown domain: taiphanmemfacebookmoi.info
# unknown domain: download.com.vn
# unknown domain: nhaccuatui.android.zyngacdn.com
# unknown domain: inc.graceneufville.com

# %%
json_output = json.dumps(domain, indent = 4, default = str)
print(json_output)

with open(JSON_PATH, 'w') as f:
    f.write(json_output)
# Out:
# {
#     "src": [
#         {
#             "name": "viodger.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:35:14",
#             "expiration_date": "2021-05-16 07:35:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "log4jv.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:43:58",
#             "expiration_date": "2021-12-09 08:43:58",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "viodger.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:35:14",
#             "expiration_date": "2021-05-16 07:35:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "cerisecaird.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-06-19 03:59:29",
#             "expiration_date": "2021-06-19 03:59:29",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.zilore.net\\r', 'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r', 'ns1.zilore.net\\r'}"
#         },
#         {
#             "name": "andreagahuvrauvin.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2018-04-06 09:16:23",
#             "expiration_date": "2021-04-06 09:16:23",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "kaspersky.com",
#             "registrar": "MarkMonitor Inc.",
#             "creation_date": "1997-10-09 04:00:00",
#             "expiration_date": "2021-10-08 04:00:00",
#             "last_updated": null,
#             "status": "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#             "name_servers": "{'ns1.kasperskylabs.net\\r', 'ns2.kasperskylabs.net\\r\\r', 'ns3.kasperskylabs.net\\r\\r', 'ns1.kasperskylabs.net\\r\\r', 'ns2.kasperskylabs.net\\r', 'ns3.kasperskylabs.net\\r'}"
#         },
#         {
#             "name": "androidappsapk.co",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2015-11-20 04:07:17",
#             "expiration_date": "2021-11-19 23:59:59",
#             "last_updated": "2020-10-26 09:57:34",
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'mona.ns.cloudflare.com\\r\\r', 'mona.ns.cloudflare.com\\r', 'thomas.ns.cloudflare.com\\r', 'thomas.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "remaariegarcia.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2019-10-17 08:07:59",
#             "expiration_date": "2021-10-17 08:07:59",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "stralisemariegar.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2019-10-17 08:12:25",
#             "expiration_date": "2021-10-17 08:12:25",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "jaxonsorensen.club",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2018-06-18 03:30:14",
#             "expiration_date": "2021-06-18 03:30:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "viperse.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2019-03-10 07:33:26",
#             "expiration_date": "2021-03-10 07:33:26",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "sqllitlever.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:46:06",
#             "expiration_date": "2021-12-09 08:46:06",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "anaehler.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:38:55",
#             "expiration_date": "2021-05-16 07:38:55",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "tin247.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2007-09-09 05:51:51",
#             "expiration_date": "2022-09-09 05:51:51",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'minh778160.earth.orderbox-dns.com\\r', 'minh778160.mercury.orderbox-dns.com\\r\\r', 'minh778160.earth.orderbox-dns.com\\r\\r', 'minh778160.venus.orderbox-dns.com\\r\\r', 'minh778160.mars.orderbox-dns.com\\r\\r', 'minh778160.mars.orderbox-dns.com\\r', 'minh778160.mercury.orderbox-dns.com\\r', 'minh778160.venus.orderbox-dns.com\\r'}"
#         },
#         {
#             "name": "mediafire.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2002-08-11 15:31:16",
#             "expiration_date": "2025-08-11 15:31:16",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'lisa.ns.cloudflare.com\\r', 'ken.ns.cloudflare.com\\r\\r', 'ken.ns.cloudflare.com\\r', 'lisa.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "dmkatti.com",
#             "registrar": "Xin Net Technology Corporation",
#             "creation_date": "2019-08-11 15:05:22",
#             "expiration_date": "2021-08-11 15:05:22",
#             "last_updated": null,
#             "status": "ok https://icann.org/epp#ok",
#             "name_servers": "{'jm1.dns.com\\r\\r', 'jm1.dns.com\\r', 'jm2.dns.com\\r\\r', 'jm2.dns.com\\r'}"
#         },
#         {
#             "name": "illagedrivestralia.xyz",
#             "registrar": "Namecheap",
#             "creation_date": "2018-04-06 10:34:05",
#             "expiration_date": "2021-04-06 23:59:59",
#             "last_updated": "2020-05-14 11:58:47",
#             "status": "serverHold https://icann.org/epp#serverHold",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "anofrio.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:37:15",
#             "expiration_date": "2021-05-16 07:37:15",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "shoreoa.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2018-02-01 09:40:29",
#             "expiration_date": "2022-02-01 09:40:29",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns10.parkpage.foundationapi.com\\r\\r', 'dns11.parkpage.foundationapi.com\\r', 'dns11.parkpage.foundationapi.com\\r\\r', 'dns10.parkpage.foundationapi.com\\r'}"
#         },
#         {
#             "name": "ettebiermahalet.com",
#             "registrar": "Hostinger, UAB",
#             "creation_date": "2019-10-18 04:07:48",
#             "expiration_date": "2021-10-18 04:07:48",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns5.he.net\\r', 'ns2.he.net\\r', 'ns2.he.net\\r\\r', 'ns4.he.net\\r\\r', 'ns3.he.net\\r', 'ns3.he.net\\r\\r', 'ns4.he.net\\r', 'ns5.he.net\\r\\r'}"
#         },
#         {
#             "name": "apkpure.com",
#             "registrar": "eNom, LLC",
#             "creation_date": "2014-11-28 11:29:15",
#             "expiration_date": "2021-11-28 11:29:15",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'elma.ns.cloudflare.com\\r\\r', 'adam.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "catalinabonami.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-06-18 04:28:37",
#             "expiration_date": "2021-06-18 04:28:37",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.zilore.net\\r', 'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r', 'ns1.zilore.net\\r'}"
#         },
#         {
#             "name": "mediafire.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2002-08-11 15:31:16",
#             "expiration_date": "2025-08-11 15:31:16",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'lisa.ns.cloudflare.com\\r', 'ken.ns.cloudflare.com\\r\\r', 'ken.ns.cloudflare.com\\r', 'lisa.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "christienollmache.xyz",
#             "registrar": "Namecheap",
#             "creation_date": "2018-04-06 10:33:55",
#             "expiration_date": "2021-04-06 23:59:59",
#             "last_updated": "2020-05-14 11:58:47",
#             "status": "serverHold https://icann.org/epp#serverHold",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "arkouthrie.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2018-02-01 09:38:47",
#             "expiration_date": "2022-02-01 09:38:47",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns10.parkpage.foundationapi.com\\r\\r', 'dns11.parkpage.foundationapi.com\\r', 'dns11.parkpage.foundationapi.com\\r\\r', 'dns10.parkpage.foundationapi.com\\r'}"
#         },
#         {
#             "name": "log4jv.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:43:58",
#             "expiration_date": "2021-12-09 08:43:58",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "halettebiermann.com",
#             "registrar": "Hostinger, UAB",
#             "creation_date": "2019-10-18 04:06:51",
#             "expiration_date": "2021-10-18 04:06:51",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns5.he.net\\r', 'ns2.he.net\\r', 'ns2.he.net\\r\\r', 'ns4.he.net\\r\\r', 'ns3.he.net\\r', 'ns3.he.net\\r\\r', 'ns4.he.net\\r', 'ns5.he.net\\r\\r'}"
#         },
#         {
#             "name": "kristianfiedler.club",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2018-06-18 03:30:14",
#             "expiration_date": "2021-06-18 03:30:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "viperse.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2019-03-10 07:33:26",
#             "expiration_date": "2021-03-10 07:33:26",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "hiahornber.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-02-01 10:05:43",
#             "expiration_date": "2022-02-01 10:05:43",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "sqllitlever.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:46:06",
#             "expiration_date": "2021-12-09 08:46:06",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "anaehler.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:38:55",
#             "expiration_date": "2021-05-16 07:38:55",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         }
#     ],
#     "img": [
#         {
#             "name": "viodger.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:35:14",
#             "expiration_date": "2021-05-16 07:35:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "log4jv.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:43:58",
#             "expiration_date": "2021-12-09 08:43:58",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "viodger.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:35:14",
#             "expiration_date": "2021-05-16 07:35:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "cerisecaird.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-06-19 03:59:29",
#             "expiration_date": "2021-06-19 03:59:29",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.zilore.net\\r', 'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r', 'ns1.zilore.net\\r'}"
#         },
#         {
#             "name": "andreagahuvrauvin.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2018-04-06 09:16:23",
#             "expiration_date": "2021-04-06 09:16:23",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "kaspersky.com",
#             "registrar": "MarkMonitor Inc.",
#             "creation_date": "1997-10-09 04:00:00",
#             "expiration_date": "2021-10-08 04:00:00",
#             "last_updated": null,
#             "status": "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#             "name_servers": "{'ns1.kasperskylabs.net\\r', 'ns2.kasperskylabs.net\\r\\r', 'ns3.kasperskylabs.net\\r\\r', 'ns1.kasperskylabs.net\\r\\r', 'ns2.kasperskylabs.net\\r', 'ns3.kasperskylabs.net\\r'}"
#         },
#         {
#             "name": "androidappsapk.co",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2015-11-20 04:07:17",
#             "expiration_date": "2021-11-19 23:59:59",
#             "last_updated": "2020-10-26 09:57:34",
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'mona.ns.cloudflare.com\\r\\r', 'mona.ns.cloudflare.com\\r', 'thomas.ns.cloudflare.com\\r', 'thomas.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "remaariegarcia.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2019-10-17 08:07:59",
#             "expiration_date": "2021-10-17 08:07:59",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "stralisemariegar.com",
#             "registrar": "Internet Domain Service BS Corp",
#             "creation_date": "2019-10-17 08:12:25",
#             "expiration_date": "2021-10-17 08:12:25",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r'}"
#         },
#         {
#             "name": "viperse.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2019-03-10 07:33:26",
#             "expiration_date": "2021-03-10 07:33:26",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "sqllitlever.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:46:06",
#             "expiration_date": "2021-12-09 08:46:06",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "anaehler.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:38:55",
#             "expiration_date": "2021-05-16 07:38:55",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "anaehler.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:38:55",
#             "expiration_date": "2021-05-16 07:38:55",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "tin247.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2007-09-09 05:51:51",
#             "expiration_date": "2022-09-09 05:51:51",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'minh778160.earth.orderbox-dns.com\\r', 'minh778160.mercury.orderbox-dns.com\\r\\r', 'minh778160.earth.orderbox-dns.com\\r\\r', 'minh778160.venus.orderbox-dns.com\\r\\r', 'minh778160.mars.orderbox-dns.com\\r\\r', 'minh778160.mars.orderbox-dns.com\\r', 'minh778160.mercury.orderbox-dns.com\\r', 'minh778160.venus.orderbox-dns.com\\r'}"
#         },
#         {
#             "name": "mediafire.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2002-08-11 15:31:16",
#             "expiration_date": "2025-08-11 15:31:16",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'lisa.ns.cloudflare.com\\r', 'ken.ns.cloudflare.com\\r\\r', 'ken.ns.cloudflare.com\\r', 'lisa.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "dmkatti.com",
#             "registrar": "Xin Net Technology Corporation",
#             "creation_date": "2019-08-11 15:05:22",
#             "expiration_date": "2021-08-11 15:05:22",
#             "last_updated": null,
#             "status": "ok https://icann.org/epp#ok",
#             "name_servers": "{'jm1.dns.com\\r\\r', 'jm1.dns.com\\r', 'jm2.dns.com\\r\\r', 'jm2.dns.com\\r'}"
#         },
#         {
#             "name": "illagedrivestralia.xyz",
#             "registrar": "Namecheap",
#             "creation_date": "2018-04-06 10:34:05",
#             "expiration_date": "2021-04-06 23:59:59",
#             "last_updated": "2020-05-14 11:58:47",
#             "status": "serverHold https://icann.org/epp#serverHold",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "sqllitlever.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:46:06",
#             "expiration_date": "2021-12-09 08:46:06",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "anofrio.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2017-05-16 07:37:15",
#             "expiration_date": "2021-05-16 07:37:15",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "shoreoa.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2018-02-01 09:40:29",
#             "expiration_date": "2022-02-01 09:40:29",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns10.parkpage.foundationapi.com\\r\\r', 'dns11.parkpage.foundationapi.com\\r', 'dns11.parkpage.foundationapi.com\\r\\r', 'dns10.parkpage.foundationapi.com\\r'}"
#         },
#         {
#             "name": "ettebiermahalet.com",
#             "registrar": "Hostinger, UAB",
#             "creation_date": "2019-10-18 04:07:48",
#             "expiration_date": "2021-10-18 04:07:48",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns5.he.net\\r', 'ns2.he.net\\r', 'ns2.he.net\\r\\r', 'ns4.he.net\\r\\r', 'ns3.he.net\\r', 'ns3.he.net\\r\\r', 'ns4.he.net\\r', 'ns5.he.net\\r\\r'}"
#         },
#         {
#             "name": "apkpure.com",
#             "registrar": "eNom, LLC",
#             "creation_date": "2014-11-28 11:29:15",
#             "expiration_date": "2021-11-28 11:29:15",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'elma.ns.cloudflare.com\\r\\r', 'adam.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "catalinabonami.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-06-18 04:28:37",
#             "expiration_date": "2021-06-18 04:28:37",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.zilore.net\\r', 'ns1.zilore.net\\r\\r', 'ns2.zilore.net\\r\\r', 'ns1.zilore.net\\r'}"
#         },
#         {
#             "name": "mediafire.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2002-08-11 15:31:16",
#             "expiration_date": "2025-08-11 15:31:16",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'lisa.ns.cloudflare.com\\r', 'ken.ns.cloudflare.com\\r\\r', 'ken.ns.cloudflare.com\\r', 'lisa.ns.cloudflare.com\\r\\r'}"
#         },
#         {
#             "name": "christienollmache.xyz",
#             "registrar": "Namecheap",
#             "creation_date": "2018-04-06 10:33:55",
#             "expiration_date": "2021-04-06 23:59:59",
#             "last_updated": "2020-05-14 11:58:47",
#             "status": "serverHold https://icann.org/epp#serverHold",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "arkouthrie.com",
#             "registrar": "PDR Ltd. d/b/a PublicDomainRegistry.com",
#             "creation_date": "2018-02-01 09:38:47",
#             "expiration_date": "2022-02-01 09:38:47",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns10.parkpage.foundationapi.com\\r\\r', 'dns11.parkpage.foundationapi.com\\r', 'dns11.parkpage.foundationapi.com\\r\\r', 'dns10.parkpage.foundationapi.com\\r'}"
#         },
#         {
#             "name": "log4jv.info",
#             "registrar": "Namesilo, LLC",
#             "creation_date": "2015-12-09 08:43:58",
#             "expiration_date": "2021-12-09 08:43:58",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.qhoster.net\\r', 'ns2.qhoster.net\\r\\r', 'ns3.qhoster.net\\r\\r', 'ns1.qhoster.net\\r\\r', 'ns4.qhoster.net\\r\\r', 'ns4.qhoster.net\\r', 'ns1.qhoster.net\\r', 'ns3.qhoster.net\\r'}"
#         },
#         {
#             "name": "halettebiermann.com",
#             "registrar": "Hostinger, UAB",
#             "creation_date": "2019-10-18 04:06:51",
#             "expiration_date": "2021-10-18 04:06:51",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns5.he.net\\r', 'ns2.he.net\\r', 'ns2.he.net\\r\\r', 'ns4.he.net\\r\\r', 'ns3.he.net\\r', 'ns3.he.net\\r\\r', 'ns4.he.net\\r', 'ns5.he.net\\r\\r'}"
#         },
#         {
#             "name": "kristianfiedler.club",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2018-06-18 03:30:14",
#             "expiration_date": "2021-06-18 03:30:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "viperse.com",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2019-03-10 07:33:26",
#             "expiration_date": "2021-03-10 07:33:26",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         },
#         {
#             "name": "hiahornber.com",
#             "registrar": "NameSilo, LLC",
#             "creation_date": "2018-02-01 10:05:43",
#             "expiration_date": "2022-02-01 10:05:43",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'ns2.dnsowl.com\\r\\r', 'ns1.dnsowl.com\\r', 'ns3.dnsowl.com\\r\\r', 'ns3.dnsowl.com\\r', 'ns2.dnsowl.com\\r', 'ns1.dnsowl.com\\r\\r'}"
#         },
#         {
#             "name": "jaxonsorensen.club",
#             "registrar": "NameCheap, Inc.",
#             "creation_date": "2018-06-18 03:30:14",
#             "expiration_date": "2021-06-18 03:30:14",
#             "last_updated": null,
#             "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#             "name_servers": "{'dns2.registrar-servers.com\\r', 'dns1.registrar-servers.com\\r\\r', 'dns2.registrar-servers.com\\r\\r', 'dns1.registrar-servers.com\\r'}"
#         }
#     ]
# }
